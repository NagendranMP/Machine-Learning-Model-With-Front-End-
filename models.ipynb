# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
def select_k_algorithm(X,y,n):
    algorithm=SelectKBest(chi2,k=n)
    fit1=algorithm.fit(X,y)
    result=fit1.transform(X)
    return result

# %%
def standarscalar(X,y):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)
    sc=StandardScaler()
    X_train=sc.fit_transform(X_train)
    X_test=sc.transform(X_test)
    return X_train,X_test,y_train,y_test

# %%
def classification_test(classifier,X_test):
    y_pred=classifier.predict(X_test)
    Confution_Matrix=confusion_matrix(y_test,y_pred)
    Classification_Report=classification_report(y_test,y_pred)
    Accuracy=accuracy_score(y_test,y_pred)
    return classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix

# %%
def LR(X_train,y_train,X_test):
    classifier=LogisticRegression(random_state=0)
    classifier.fit(X_train,y_train)
    classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=classification_test(classifier,X_test)
    return classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix

# %%
def KNN(X_train,y_train,X_test):
    classifier=KNeighborsClassifier(n_neighbors=5,metric="minkowski",p=2)
    classifier.fit(X_train,y_train)
    classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=classification_test(classifier,X_test)
    return classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix

# %%
def SVM(X_train,y_train,X_test):
    classifier=SVC(kernel="linear",random_state=0)
    classifier.fit(X_train,y_train)
    classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=classification_test(classifier,X_test)
    return classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix

# %%
def RF(X_train,y_train,X_test):
    classifier=RandomForestClassifier(n_estimators=10,criterion="entropy",random_state=0)
    classifier.fit(X_train,y_train)
    classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=classification_test(classifier,X_test)
    return classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix

# %%
def DT(X_train,y_train,X_test):
    classifier=DecisionTreeClassifier(criterion="entropy",random_state=0)
    classifier.fit(X_train,y_train)
    classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=classification_test(classifier,X_test)
    return classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix

# %%
df=pd.read_csv("pre-kidney_disease.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   id   age    bp     sg   al   su    bgr    bu   sc  ...  \
# 0           0  0.0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2  ...
# 1           1  1.0   7.0  50.0  1.020  4.0  0.0   99.0  18.0  0.8  ...
# 2           2  2.0  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8  ...
# 3           3  3.0  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  ...
# 4           4  4.0  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4  ...
#
#          pc         pcc          ba  htn   dm  cad appet   pe  ane  \
# 0    normal  notpresent  notpresent  yes  yes   no  good   no   no
# 1    normal  notpresent  notpresent   no   no   no  good   no   no
# 2    normal  notpresent  notpresent   no  yes   no  poor   no  yes
# 3  abnormal     present  notpresent  yes   no   no  poor  yes  yes
# 4    normal  notpresent  notpresent   no   no   no  good   no   no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3            ckd
# 4            ckd
#
# [5 rows x 27 columns]

# %%
from sklearn.preprocessing import LabelEncoder
def QuanQual(df):
        quan=[]
        qual=[]
        for i in df:
            if df[i].dtype=="O":
                qual.append(i)
            else:
                quan.append(i)
        return quan,qual
quan,qual=QuanQual(df)

# %%
l=LabelEncoder()
for i in qual:
    df[i]=l.fit_transform(df[i])

# %%
X=df.drop("classification",axis=1)
y=df["classification"]

# %%
select_k=select_k_algorithm(X,y,5)
log=[]
knn=[]
svm1=[]
rf=[]
dt=[]

# %%
X_train,X_test,y_train,y_test=standarscalar(select_k,y)

# %%
classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=LR(X_train,y_train,X_test)
log.append(Accuracy)
classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=KNN(X_train,y_train,X_test)
knn.append(Accuracy)
classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=SVM(X_train,y_train,X_test)
svm1.append(Accuracy)
classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=RF(X_train,y_train,X_test)
rf.append(Accuracy)
classifier,Accuracy,Classification_Report,X_test,y_test,Confution_Matrix=DT(X_train,y_train,X_test)
dt.append(Accuracy)
# Out:
# c:\Users\Nagendran\Desktop\kidney_Disease_front_end\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Nagendran\Desktop\kidney_Disease_front_end\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Nagendran\Desktop\kidney_Disease_front_end\myenv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
dataframe=pd.DataFrame(columns=["LR","KNN","SVM","RF","DT"],index=["CHI_SQUARE"])
for i,j in enumerate(dataframe.index):
    dataframe["LR"][j]=log[0]
    dataframe["KNN"][j]=knn[0]
    dataframe["SVM"][j]=svm1[0]
    dataframe["RF"][j]=rf[0]
    dataframe["DT"][j]=dt[0]
# Out:
# C:\Users\Nagendran\AppData\Local\Temp\ipykernel_8304\1217928399.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe["LR"][j]=log[0]
# C:\Users\Nagendran\AppData\Local\Temp\ipykernel_8304\1217928399.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe["KNN"][j]=knn[0]
# C:\Users\Nagendran\AppData\Local\Temp\ipykernel_8304\1217928399.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe["SVM"][j]=svm1[0]
# C:\Users\Nagendran\AppData\Local\Temp\ipykernel_8304\1217928399.py:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe["RF"][j]=rf[0]
# C:\Users\Nagendran\AppData\Local\Temp\ipykernel_8304\1217928399.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataframe["DT"][j]=dt[0]

# %%
#select_k=5
dataframe
# Out:
#                   LR       KNN       SVM        RF        DT
# CHI_SQUARE  0.983333  0.983333  0.983333  0.991667  0.983333

# %%
def QuanQual(df):
        quan=[]
        qual=[]
        for i in df:
            if df[i].dtype=="O":
                qual.append(i)
            else:
                quan.append(i)
        return quan,qual
quan,qual=QuanQual(df)

# %%
l=LabelEncoder()
for i in qual:
    df[i]=l.fit_transform(df[i])

# %%
df=df.drop(["Unnamed: 0","id","age"],axis=1)
X=df.drop("classification",axis=1)
y=df["classification"]

# %%
import joblib
algorithm=SelectKBest(chi2,k=5)
result=algorithm.fit(X,y)
fe=result.get_support()
result=result.transform(X)
X_train,X_test,y_train,y_test=train_test_split(result,y,test_size=0.3,random_state=42)
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
joblib.dump(sc,"scalar.pkl")
classifier=LogisticRegression(random_state=0)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred=classifier.predict(X_test)
Confution_Matrix=confusion_matrix(y_test,y_pred)
Classification_Report=classification_report(y_test,y_pred)
Accuracy=accuracy_score(y_test,y_pred)

# %%
df.columns
# Out:
# Index(['bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv',
#        'wc', 'rc', 'rbc', 'pc', 'pcc', 'ba', 'htn', 'dm', 'cad', 'appet', 'pe',
#        'ane', 'classification'],
#       dtype='object')

# %%
selected_feature=[]
for i,j in enumerate(fe):
    if j==True:
        selected_feature.append(df.columns[i])
selected_feature
# Out:
# ['bgr', 'bu', 'sc', 'pcv', 'wc']

# %%
Accuracy
# Out:
# 0.9083333333333333

# %%
import pickle
filename="after.pkl"
pickle.dump(classifier,open(filename,"wb"))

# %%
le=df[selected_feature]
le
# Out:
#        bgr    bu   sc   pcv      wc
# 0    121.0  36.0  1.2  44.0  7800.0
# 1     99.0  18.0  0.8  38.0  6000.0
# 2    423.0  53.0  1.8  31.0  7500.0
# 3    117.0  56.0  3.8  32.0  6700.0
# 4    106.0  26.0  1.4  35.0  7300.0
# ..     ...   ...  ...   ...     ...
# 395  140.0  49.0  0.5  47.0  6700.0
# 396   75.0  31.0  1.2  54.0  7800.0
# 397  100.0  26.0  0.6  49.0  6600.0
# 398  114.0  50.0  1.0  51.0  7200.0
# 399  131.0  18.0  1.1  53.0  6800.0
#
# [400 rows x 5 columns]

# %%
df["classification"].value_counts()
# Out:
# classification
# 0    248
# 2    150
# 1      2
# Name: count, dtype: int64

# %%
mf=pd.read_csv("pre-kidney_disease.csv")
mf["classification"].value_counts()
# Out:
# classification
# ckd       248
# notckd    150
# ckd\t       2
# Name: count, dtype: int64

# %%
mf[mf["classification"]=="ckd"]["id"]
# Out:
# 0        0.0
# 1        1.0
# 2        2.0
# 3        3.0
# 4        4.0
#        ...
# 245    245.0
# 246    246.0
# 247    247.0
# 248    248.0
# 249    249.0
# Name: id, Length: 248, dtype: float64

# %%
mf[mf["classification"]=="notckd"]["id"]
# Out:
# 250    250.0
# 251    251.0
# 252    252.0
# 253    253.0
# 254    254.0
#        ...
# 395    395.0
# 396    396.0
# 397    397.0
# 398    398.0
# 399    399.0
# Name: id, Length: 150, dtype: float64

# %%
le.iloc[246]
# Out:
# bgr     106.0
# bu      215.0
# sc       15.2
# pcv      26.0
# wc     5000.0
# Name: 246, dtype: float64
